# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('diabetes2.csv')

# %%
df.head()
# Out:
#    SEX  BTH_G  SBP  DBP  FBS  DIS   BMI
# 0    1      1  116   78   94    4  16.6
# 1    1      1  100   60   79    4  22.3
# 2    1      1  100   60   87    4  21.9
# 3    1      1  111   70   72    4  20.2
# 4    1      1  120   80   98    4  20.0

# %%
df.describe()
# Out:
#                   SEX           BTH_G             SBP             DBP  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         1.489773       13.905268      121.871763       75.787874
# std          0.499896        7.006442       14.561706        9.793411
# min          1.000000        1.000000       82.000000       50.000000
# 25%          1.000000        9.000000      110.000000       70.000000
# 50%          1.000000       14.000000      120.000000       76.000000
# 75%          2.000000       19.000000      130.000000       80.000000
# max          2.000000       27.000000      190.000000      120.000000
#
#                   FBS             DIS             BMI
# count  1000000.000000  1000000.000000  1000000.000000
# mean        98.864428        3.471040       23.804029
# std         22.981300        0.946151        3.297287
# min         60.000000        1.000000       14.800000
# 25%         87.000000        3.000000       21.500000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 7 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   SEX     1000000 non-null  int64
#  1   BTH_G   1000000 non-null  int64
#  2   SBP     1000000 non-null  int64
#  3   DBP     1000000 non-null  int64
#  4   FBS     1000000 non-null  int64
#  5   DIS     1000000 non-null  int64
#  6   BMI     1000000 non-null  float64
# dtypes: float64(1), int64(6)
# memory usage: 53.4 MB

# %%
df['DIS'].replace(2,5, inplace=True)

# %%
df['DIS'].replace(4,5, inplace=True)

# %%
df['DIS'].replace(3,2, inplace=True)

# %%
df['DIS'].replace(5,0, inplace=True)

# %%
df['DIS'].replace(2,1, inplace=True)

# %%
df.describe()
# Out:
#                   SEX           BTH_G             SBP             DBP  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         1.489773       13.630618      121.871763       75.787874
# std          0.499896        7.470263       14.561706        9.793411
# min          1.000000        0.000000       82.000000       50.000000
# 25%          1.000000        9.000000      110.000000       70.000000
# 50%          1.000000       14.000000      120.000000       76.000000
# 75%          2.000000       19.000000      130.000000       80.000000
# max          2.000000       27.000000      190.000000      120.000000
#
#                   FBS             DIS             BMI
# count  1000000.000000  1000000.000000  1000000.000000
# mean        98.864428        0.096512       23.804029
# std         22.981300        0.295292        3.297287
# min         60.000000        0.000000       14.800000
# 25%         87.000000        0.000000       21.500000
# ...

# %%
df['SEX'].replace(2,1, inplace=True)

# %%
df['BTH_G'].replace([1,2,3,4],0, inplace=True)

# %%
df['BTH_G'].replace([5,6,7,8,9],1, inplace=True)

# %%
df['BTH_G'].replace([10,11,12,13,14],2, inplace=True)

# %%
df['BTH_G'].replace([15,16,17,18,19],3, inplace=True)

# %%
df['BTH_G'].replace([20,21,22,23,24],4, inplace=True)

# %%
df['BTH_G'].replace([25,26,27,28,20],5, inplace=True)

# %%
df = df[['SEX', 'SBP', 'DBP', 'FBS', 'BMI','BTH_G_1', 'BTH_G_2',
       'BTH_G_3', 'BTH_G_4', 'BTH_G_5','DIS', ]]

# %%
df.drop('DBP',axis=1)
# Out:
#         SEX  BTH_G  SBP  FBS   BMI  DIS
# 0         1      0  116   94  16.6    0
# 1         1      0  100   79  22.3    0
# 2         1      0  100   87  21.9    0
# 3         1      0  111   72  20.2    0
# 4         1      0  120   98  20.0    0
# ...     ...    ...  ...  ...   ...  ...
# 999995    2      5  120   81  23.1    0
# 999996    2      5  110  104  27.2    0
# 999997    2      5  115  110  25.2    1
# 999998    2      5  120   90  19.7    0
# 999999    2      5  116   92  17.6    0
#
# [1000000 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['SEX', 'SBP', 'DBP', 'FBS', 'BMI', 'DIS', 'BTH_G_1', 'BTH_G_2',
#        'BTH_G_3', 'BTH_G_4', 'BTH_G_5'],
#       dtype='object')

# %%
df.head()
# Out:
#    SEX  SBP  DBP  FBS   BMI  BTH_G_1  BTH_G_2  BTH_G_3  BTH_G_4  BTH_G_5  DIS
# 0    0  116   78   94  16.6        0        0        0        0        0    0
# 1    0  100   60   79  22.3        0        0        0        0        0    0
# 2    0  100   60   87  21.9        0        0        0        0        0    0
# 3    0  111   70   72  20.2        0        0        0        0        0    0
# 4    0  120   80   98  20.0        0        0        0        0        0    0

# %%
df.describe()
# Out:
#                   SEX           BTH_G             SBP             DBP  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.489773        2.391942      121.871763       75.787874
# std          0.499896        1.435680       14.561706        9.793411
# min          0.000000        0.000000       82.000000       50.000000
# 25%          0.000000        1.000000      110.000000       70.000000
# 50%          0.000000        2.000000      120.000000       76.000000
# 75%          1.000000        3.000000      130.000000       80.000000
# max          1.000000        5.000000      190.000000      120.000000
#
#                   FBS             BMI             DIS
# count  1000000.000000  1000000.000000  1000000.000000
# mean        98.864428       23.804029        0.096512
# std         22.981300        3.297287        0.295292
# min         60.000000       14.800000        0.000000
# 25%         87.000000       21.500000        0.000000
# ...

# %%
df.head()
# Out:
#    SEX  BTH_G  SBP  DBP  FBS  BMI   DIS
# 0    1      0  116   78   94    0  16.6
# 1    1      0  100   60   79    0  22.3
# 2    1      0  100   60   87    0  21.9
# 3    1      0  111   70   72    0  20.2
# 4    1      0  120   80   98    0  20.0

# %%
col_list = ['BTH_G']
df = pd.get_dummies(df, columns=col_list, drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-aa2554b05ec2> in <module>
#       1 col_list = ['BTH_G']
# ----> 2 df = pd.get_dummies(df, columns=col_list, drop_first=True)
#       3 df.head(20)
#
# ~\anaconda3\envs\AI_dev\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     845             raise TypeError("Input must be a list-like for parameter `columns`")
#     846         else:
# --> 847             data_to_encode = data[columns]
#     848
#     849         # validate prefixes and separator to avoid silently dropping cols
#
# ~\anaconda3\envs\AI_dev\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# ...

# %%
df.head(50)
# Out:
#     SEX  SBP  DBP  FBS   BMI  DIS  BTH_G_1  BTH_G_2  BTH_G_3  BTH_G_4  BTH_G_5
# 0     0  116   78   94  16.6    0        0        0        0        0        0
# 1     0  100   60   79  22.3    0        0        0        0        0        0
# 2     0  100   60   87  21.9    0        0        0        0        0        0
# 3     0  111   70   72  20.2    0        0        0        0        0        0
# 4     0  120   80   98  20.0    0        0        0        0        0        0
# 5     0  115   79   95  23.1    0        0        0        0        0        0
# 6     0  110   70   80  20.6    0        0        0        0        0        0
# 7     0  115   75   80  22.6    0        0        0        0        0        0
# 8     0  130   80   90  28.4    0        0        0        0        0        0
# 9     0  100   65   95  21.7    0        0        0        0        0        0
# 10    0  111   76   94  21.4    0        0        0        0        0        0
# ...

# %%
df['DIS'].value_counts(normalize=True)
# Out:
# 0    0.903488
# 1    0.096512
# Name: DIS, dtype: float64

# %%
for i, col in enumerate(df):
    try:
        plt.figure(figsize=(10, 5))
        sns.distplot(df[col][df['DIS']==0])
        sns.distplot(df[col][df['DIS']==1])
        plt.legend(['0', '1'], loc='best')
        plt.title('histogram of features '+str(col))
        plt.show()
        
    
    except:
        pass

# %%
# 상관관계 시각화
plt.figure(figsize=(15, 15))
sns.set(font_scale=2)
sns.heatmap(data=df.iloc[:, :-1].corr(), annot=True, fmt='.3f', cmap='Blues', 
           linewidths=.5, annot_kws={"size": 20})
# Out:
# <AxesSubplot:>

# %%
df.hist(figsize =(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'SEX'}>,
#         <AxesSubplot:title={'center':'BTH_G'}>,
#         <AxesSubplot:title={'center':'SBP'}>],
#        [<AxesSubplot:title={'center':'DBP'}>,
#         <AxesSubplot:title={'center':'FBS'}>,
#         <AxesSubplot:title={'center':'BMI'}>],
#        [<AxesSubplot:title={'center':'DIS'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ## 머신러닝 모델

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, :-1].values, df.iloc[:, -1].values, test_size=0.15, random_state=42)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (850000, 10) (150000, 10) (850000,) (150000,)

# %%
# DecisionTreeClassifier
clf_dt = DecisionTreeClassifier()
clf_dt.fit(X_train, y_train)
dt_score = clf_dt.score(X_test, y_test)
print("Decision Tree score: ", dt_score)
# Out:
# Decision Tree score:  0.8819466666666667

# %%
ftr_importances_values = clf_dt.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index=df.columns[:-1])

ftr_top = ftr_importances.sort_values(ascending=False)
plt.figure(figsize=(8, 6))
sns.barplot(x=ftr_top, y=ftr_top.index)
plt.show()

print(ftr_importances)
# Out:
# SEX        0.025918
# SBP        0.156334
# DBP        0.119522
# FBS        0.417777
# BMI        0.233308
# BTH_G_1    0.006963
# BTH_G_2    0.006652
# BTH_G_3    0.005908
# BTH_G_4    0.013548
# BTH_G_5    0.014070
# dtype: float64

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.metrics import AUC

# %%
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, :-1].values, df.iloc[:, -1].values, test_size=0.15, random_state=42)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3)

# %%
print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
# Out:
# (595000, 10) (255000, 10) (595000,) (255000,)

# %%
model = Sequential()
model.add(Dense(16, activation='relu', input_shape=(10,)))
model.add(Dropout(0.4))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop',
             loss='binary_crossentropy',
             metrics=['accuracy'])

# %%
model_com = model.fit(X_train, y_train, epochs=15, validation_data=(X_val, y_val))
# Out:
# Epoch 1/15
# 18594/18594 [==============================] - 14s 725us/step - loss: 0.3371 - accuracy: 0.9130 - val_loss: 0.2327 - val_accuracy: 0.9178
# Epoch 2/15
# 18594/18594 [==============================] - 14s 755us/step - loss: 0.2369 - accuracy: 0.9192 - val_loss: 0.2331 - val_accuracy: 0.9167
# Epoch 3/15
# 18594/18594 [==============================] - 15s 818us/step - loss: 0.2353 - accuracy: 0.9201 - val_loss: 0.2301 - val_accuracy: 0.9149
# Epoch 4/15
# 18594/18594 [==============================] - 15s 817us/step - loss: 0.2350 - accuracy: 0.9199 - val_loss: 0.2289 - val_accuracy: 0.9138
# Epoch 5/15
# 18594/18594 [==============================] - 15s 784us/step - loss: 0.2317 - accuracy: 0.9210 - val_loss: 0.2271 - val_accuracy: 0.9115
# Epoch 6/15
# 18594/18594 [==============================] - 14s 767us/step - loss: 0.2316 - accuracy: 0.9208 - val_loss: 0.2271 - val_accuracy: 0.9125
# Epoch 7/15
# ...

# %%
history_dict = model_com.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1,len(loss)+1)
plt.figure(figsize=(7,3))
plt.plot(epochs, val_loss, 'b', label='Validation loss')

plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
